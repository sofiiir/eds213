# %% [markdown]
# # Exploring the ASDN data

# %%
import pandas as pd

# %%
# load in the data
ASDN_survey = pd.read_csv("data/ASDN_Snow_survey.csv")

# %%
# view the data
ASDN_survey.head()
# Out:
#    Site  Year        Date  Plot Location  Snow_cover  Water_cover  Land_cover  \
# 0  barr  2011  2011-05-29  brw1      b10        90.0          0.0        10.0
# 1  barr  2011  2011-05-29  brw1      b12       100.0          0.0         0.0
# 2  barr  2011  2011-05-29  brw1       b2        90.0          0.0        10.0
# 3  barr  2011  2011-05-29  brw1       b4       100.0          0.0         0.0
# 4  barr  2011  2011-05-29  brw1       b6        95.0          0.0         5.0
#
#    Total_cover Observer Notes
# 0        100.0    adoll   NaN
# 1        100.0    adoll   NaN
# 2        100.0    adoll   NaN
# 3        100.0    adoll   NaN
# 4        100.0    adoll   NaN

# %%
# explore the data types of the data
ASDN_survey.dtypes
# Out:
# Site            object
# Year             int64
# Date            object
# Plot            object
# Location        object
# Snow_cover     float64
# Water_cover    float64
# Land_cover     float64
# Total_cover    float64
# Observer        object
# Notes           object
# dtype: object
